# %%
buck2uni = { "e":"ا",
            "é":"ا",
            "a":"ا",
            
     "7":"ح",
             "7a": "ح",
        "7e": "ح",
        "7i": "ح",
        "7o": "ح",
        "7u": "ح",
            "5":"خ",
            "3":"ع",
     "3":"ع",
            "9":"ق",
    "9":"ق",
    "8":"غ",
            "3a": "ع",
        "3e": "ع",
        "3i":"ع",
        "3o": "ع",
        "3u": "ع",
        "5a": "خ",
        "5e": "خ",
        "5i": "خ",
        "5o": "خ",
        "5u": "خ",
            "8":"غ",
            "2": "ا",
   "a": "ا", 
           
        "b": "ب",
        "ba": "ب",
        "be": "ب",
        "bi": "ب",
        "bo": "ب",
        "bu": "ب",
        "ch": "ش",
        "cha": "ش",
        "che":"ش",
        "chi": "ش",
        "cho": "ش",
        "chu": "ش",
       
        "b": "ب",

        "ch": "ش",
    
        "d": "د",
     
       "c" : "ك",
          
       "ai": "ي",
        
        "ou" : "و",
        "th": "ذ",
             "tha": "ذ",
             "tha": "ث",
            "the":"ذ",
             "the":  "ث",
             "the":"ذ",
             "tho":   "ث",
             "tho":"ذ",
            "thi":  "ث",
            "thi":"ذ",
             "the":  "ث",
        "dh":  "ظ",
       "dh"  : "ض",
         "dha":  "ظ",
       "dha"  : "ض",
              "dhe":  "ظ",
       "dhe"  : "ض",
            
                          "dhe":  "ظ",
       "dhe"  : "ض",
            
            
            "f": "ف",
"r":  "ر",
        "ra": "ر",
        "re": "ر",
        "ri": "ر",
        "ro": "ر",
        "ru": "ر",
        "fa": "ف",
        "fe": "ف",
        "fi": "ف",
        "fo": "ف",
        "fu": "ف",
        "gh": "غ",
 "k": "ك",
        "ka": "ك",
        "ke": "ك",
        "ki":"ك",
        "ko": "ك",
        "ku":"ك",
        "kh":  "خ",
        "kha": "خ",
        "khe": "خ",
        "khi": "خ",
        "kho": "خ",
        "khu": "خ",
        "h": "ه",
        "ha": "ه",
         "gh": "غ",
        "gha": "غ",
        "ghe": "غ",
        "ghi": "غ",
        "gho":"غ",
        "ghu": "غ",
        "h": "ه",
        "ha": "ه",
        "he": "ه",
        "hi": "ه",
        "ho": "ه",
        "hu": "ه",
        "i": "ى",
                    "i": "ي",

        "ia": "ي",
        "ie": "ي",
        "ii": "ي",
        "io": "ي",
        "iu": "ي",
        "i": "ي",
        "j": "ج",
      
        "k": "ك",
        "ka": "",
    
        "kh":  "خ",
        "ch":"ش",
       
        "l":  "ل",
        "l": "ل",
    
        "m":  "م",
       
        "n":  "ن",
       
        "o":  "و",
    
        "ou": "و",
    
        "p":  "ب",
      
    
        "q":  "ك",
    
        "r":  "ر" ,
        "ra": "ر",
    
        "s":  "س",
       
     "ch": "ش",
        "sh": "ش",
        "t":  "ت",

     "t":  "ط",
        "ti": "ت",
               "ti":  "ط",
        "to": "ت",
             "to":  "ط",
        "tu": "ت",
             "tu":  "ط",
        "ta":  "ط",

        "ta": "ت",
        "te": "ت", 
            "te": "ط",

        "th":  "ث" ,
        "th":  "ذ",
    
     "t": "ت",
         "t": "ط",    
        "w": "و",
        "g": "ق",
        "ga": "ق",
        "ge": "ج",
        "y": "ي", 
      
        "v" :"ف",
         "ph" :"ف",   
        "z":  "ز",
                   "l":  "ل",
        "la": "ل",
        "le": "ل",
        "li": "ل",
        "lo": "ل",
        "lu": "ل",
        "m":  "م",
        "ma": "م",
        "me": "م",
        "mi": "م",
        "mo": "م",
        "mu": "م",
        "n":  "ن",
        "na": "ن",
        "ne": "ن",
        "ni": "ن",
        "no": "ن",
        "nu": "ن",
        "o":  "ا",
        "p":  "ب",
        "pa": "ب",
        "pe": "ب",
        "pi": "ب",
        "po": "ب",
        "pu": "ب",
             "u":  "و",
        "ua": "و",
        "ue": "و",
        "ui": "و",
        "uo": "و",
        "uu": "و",
        "w":  "و",
        "wa": "و",
        "we": "و",
        "wi": "و",
        "wo": "و",
        "wu": "و",
            "y": "ي",
            "y": "ى",
        "ya": "ي",
        "ye": "ي",
        "yi": "ي",
          
 }

# %%
def transString1(string, reverse=0):
    '''Given a Unicode string, transliterate into Buckwalter. To go from
    Buckwalter back to Unicode, set reverse=1'''

    for k, v in buck2uni.items():
        if not reverse:

            string = string.replace(v, k)

        else:
            string = string.replace(k, v)

    return string

# %%
import numpy as np # bibliotheque pour les calculs numériques
import pandas as pd #bibliotheque pour manipuler des datagrammes
import matplotlib.pyplot as plt # bibliotheque pour  traçage des graphes




# step 0 basic reading
df = pd.read_csv(r'C:/Users/DELL/Desktop/master/test_neg.csv',error_bad_lines=False) #lecture de fichier csv trainT.csv
df
# Out:
#                                                sentence  polarity  \
# 0            مالخر راك انسان بوهالي تعمل علي ماهوش راجع  Negative
# 1                                     mouch 7louwa faza  Negative
# 2                                  mabladkom 3bed tfouh  Negative
# 3     تفوه عليك علا والديك على عايلتك على اصلك على ف...  Negative
# 4                                    يليق بهذا البرنامج  Negative
# ...                                                 ...       ...
# 1691                           شبعة خمجاينما يقيم الجهل  Negative
# 1692  الانسان هذا مافهمتش شنوه دينو وشنوه انتماءاتو ...  Negative
# 1693             عار عليكم اليوم تجيبوا هالمناظر لتلفزة  Negative
# 1694               ma5ibha sahra 5ater enti faha ma9ded  Negative
# 1695           عدم إحترام المشاهد جميع الاطراف قلة حياء  Negative
#
#                                                 comment
# 0            مالخر راك انسان بوهالي تعمل علي ماهوش راجع
# 1                                        موش حلووا فازا
# ...

# %%
df["sentence"] = df["sentence"].astype(str)
df['sentence'] = df['sentence'].str.lower()
df.head()
# Out:
#                                             sentence  polarity  \
# 0         مالخر راك انسان بوهالي تعمل علي ماهوش راجع  Negative
# 1                                  mouch 7louwa faza  Negative
# 2                               mabladkom 3bed tfouh  Negative
# 3  تفوه عليك علا والديك على عايلتك على اصلك على ف...  Negative
# 4                                 يليق بهذا البرنامج  Negative
#
#                                              comment
# 0         مالخر راك انسان بوهالي تعمل علي ماهوش راجع
# 1                                     موش حلووا فازا
# 2                                مابلادكوم عباد تفوه
# 3  تفوه عليك علا والديك على عايلتك على اصلك على ف...
# 4                                 يليق بهذا البرنامج

# %%
df['comment'] = df['sentence'].apply(lambda x : transString1(x,1)  )  #apperler la fonction translator 
df
# Out:
#                                                sentence  polarity  \
# 0            مالخر راك انسان بوهالي تعمل علي ماهوش راجع  Negative
# 1                                     mouch 7louwa faza  Negative
# 2                                  mabladkom 3bed tfouh  Negative
# 3     تفوه عليك علا والديك على عايلتك على اصلك على ف...  Negative
# 4                                    يليق بهذا البرنامج  Negative
# ...                                                 ...       ...
# 1691                           شبعة خمجاينما يقيم الجهل  Negative
# 1692  الانسان هذا مافهمتش شنوه دينو وشنوه انتماءاتو ...  Negative
# 1693             عار عليكم اليوم تجيبوا هالمناظر لتلفزة  Negative
# 1694               ma5ibha sahra 5ater enti faha ma9ded  Negative
# 1695           عدم إحترام المشاهد جميع الاطراف قلة حياء  Negative
#
#                                                 comment
# 0            مالخر راك انسان بوهالي تعمل علي ماهوش راجع
# 1                                        موش حلووا فازا
# ...
